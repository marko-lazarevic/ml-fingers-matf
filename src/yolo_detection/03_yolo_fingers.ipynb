# %%
pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 24.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 99.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6960.3/8062.4 GB disk)

# %%
from pathlib import Path

DATASET_ROOT = "/kaggle/input/datasets/markolazarevi/hagrid-fingers-yolo/fingers_yolo"

for split in ["train", "val", "test"]:

    imgs = len(
        list(Path(f"{DATASET_ROOT}/images/{split}").glob("*.jpg"))
    )

    lbls = len(
        list(Path(f"{DATASET_ROOT}/labels/{split}").glob("*.txt"))
    )

    print(split, imgs, lbls)
# Out:
# train 12267 12267
# val 2629 2629
# test 2631 2631

# %%
with open(f"{DATASET_ROOT}/data.yaml", "r") as f:
    print(f.read())
# Out:
# path: /kaggle/working/hagrid_yolo
#
# train: images/train
# val: images/val
# test: images/test
#
# names:
#   0: zero
#   1: one
#   2: two
#   3: three
#   4: four
#   5: five

# %%
yaml_path = "/kaggle/working/data.yaml"

yaml_content = """
path: /kaggle/input/datasets/markolazarevi/hagrid-fingers-yolo/fingers_yolo

train: images/train
val: images/val
test: images/test

names:
  0: zero
  1: one
  2: two
  3: three
  4: four
  5: five
"""

with open(yaml_path, "w") as f:
    f.write(yaml_content)

print("YAML created:", yaml_path)
# Out:
# YAML created: /kaggle/working/data.yaml

# %%
# real gpu yolo
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/kaggle/working/data.yaml",
    epochs=25,
    imgsz=640,
    batch=8,
    device=0,

    # augmentation
    scale=0.7,
    mosaic=1.0,
    mixup=0.1,
    erasing=0.4,       # simulira delimično sakrivanje
    perspective=0.0005 # mala distorzija
)
# Out:
# ...
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
