# %%
from ultralytics import YOLO

# load smallest pretrained model
model = YOLO("yolov8n.pt")

# train
model.train(
    data="../data/data.yaml",
    epochs=10,        # fast POC
    imgsz=640,
    batch=16,
    name="yolo-poc"
)
# Out:
# Ultralytics 8.4.46 🚀 Python-3.11.10 torch-2.4.1 CPU (11th Gen Intel Core i5-1135G7 @ 2.40GHz)
# ...
